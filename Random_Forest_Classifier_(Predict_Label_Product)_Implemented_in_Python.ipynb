# %% [markdown]
# <a href="https://colab.research.google.com/github/gustiyaniz/Random-Forest-Classifier-Predict-Label-Product-Implemented-in-Python/blob/main/Random_Forest_Classifier_(Predict_Label_Product)_Implemented_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load your sales data
url = 'https://raw.githubusercontent.com/gustiyaniz/Random-Forest-Classifier-Predict-Label-Product-Implemented-in-Python/main/salesdatades23.csv'
data = pd.read_csv(url,sep=",",header=0)
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y')
# print(df info())
print('Shape of dataframe:', data.shape)
data.head()
# Out:
# Shape of dataframe: (1353, 6)
#         Date                 Product  Quantity  Sales   Cost  Profit
# 0 2024-03-08      Pulsa Indosat 10 K         1  13000  10885    2115
# 1 2024-03-08           Pulsa Xl 20 K         1  23000  20630    2370
# 2 2024-03-08  1 Gb Unlimited Indosat         1  38000  33780    4220
# 3 2024-03-08   1 Gb Indosat (3 Hari)         1   9000   6200    2800
# 4 2024-03-07            Batu Baterai         2   5000   1512    3488

# %%
# Encode the product names
label_encoder = LabelEncoder()
data['product_encoded'] = label_encoder.fit_transform(data['Product'])
data.head()
# Out:
#         Date                 Product  Quantity  Sales   Cost  Profit  \
# 0 2024-03-08      Pulsa Indosat 10 K         1  13000  10885    2115
# 1 2024-03-08           Pulsa Xl 20 K         1  23000  20630    2370
# 2 2024-03-08  1 Gb Unlimited Indosat         1  38000  33780    4220
# 3 2024-03-08   1 Gb Indosat (3 Hari)         1   9000   6200    2800
# 4 2024-03-07            Batu Baterai         2   5000   1512    3488
#
#    product_encoded
# 0               71
# 1               95
# 2                1
# 3                0
# 4               27

# %%
# Extract features and labels
features = data[['Date', 'Quantity','Sales', 'Profit', 'Cost']]
labels = data['product_encoded']

# %%
# Extract date features
features['day'] = data['Date'].dt.day
features['month'] = data['Date'].dt.month
features['year'] = data['Date'].dt.year
features['dayofweek'] = data['Date'].dt.dayofweek

# Drop the original date column
features = features.drop(columns=['Date'])
features.head()
# Out:
# <ipython-input-8-c4e18d551e83>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features['day'] = data['Date'].dt.day
#    Quantity  Sales  Profit   Cost  day  month  year  dayofweek
# 0         1  13000    2115  10885    8      3  2024          4
# 1         1  23000    2370  20630    8      3  2024          4
# 2         1  38000    4220  33780    8      3  2024          4
# 3         1   9000    2800   6200    8      3  2024          4
# 4         2   5000    3488   1512    7      3  2024          3

# %%
# Normalize numerical features
scaler = StandardScaler()
features[['Quantity', 'Sales', 'Profit', 'Cost']] = scaler.fit_transform(features[['Quantity', 'Sales', 'Profit', 'Cost']])

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize the model
model = RandomForestClassifier(n_estimators=200, random_state=42)

# Train the model
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7896678966789668
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        20
#            1       0.92      1.00      0.96        12
#            4       0.80      1.00      0.89         8
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         2
#            7       0.00      0.00      0.00         1
#            8       0.83      1.00      0.91        20
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         3
#           11       1.00      0.86      0.92         7
#           14       0.00      0.00      0.00         0
#           16       1.00      1.00      1.00         5
#           17       0.00      0.00      0.00         1
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         0
#           20       1.00      1.00      1.00        11
#           21       1.00      0.95      0.98        22
#           22       0.75      1.00      0.86         3
#           24       1.00      1.00      1.00         1
#           25       0.00      0.00      0.00         0
#           26       1.00      1.00      1.00         1
#           27       1.00      1.00      1.00         2
#           30       1.00      1.00      1.00         1
#           34       0.00      0.00      0.00         1
#           35       1.00      0.50      0.67         2
#           36       0.00      0.00      0.00         0
#           39       0.00      0.00      0.00         1
#           40       0.00      0.00      0.00         0
#           42       0.00      0.00      0.00         1
#           43       0.00      0.00      0.00         1
#           45       0.00      0.00      0.00         1
#           47       0.00      0.00      0.00         0
#           49       1.00      1.00      1.00         8
#           54       1.00      1.00      1.00         1
#           57       1.00      1.00      1.00         1
#           58       1.00      1.00      1.00         2
#           60       0.00      0.00      0.00         1
#           65       1.00      1.00      1.00         1
#           66       0.00      0.00      0.00         1
#           68       0.00      0.00      0.00         1
#           70       1.00      1.00      1.00         2
#           71       0.88      1.00      0.93        14
#           72       0.00      0.00      0.00         1
#           73       0.00      0.00      0.00         2
#           74       0.60      0.75      0.67         4
#           76       0.65      1.00      0.79        11
#           77       0.50      0.50      0.50         4
#           78       0.00      0.00      0.00         1
#           80       0.00      0.00      0.00         0
#           81       0.00      0.00      0.00         0
#           82       1.00      1.00      1.00         9
#           83       0.56      1.00      0.71         5
#           84       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           86       0.00      0.00      0.00         1
#           87       0.00      0.00      0.00         2
#           88       0.00      0.00      0.00         0
#           91       0.00      0.00      0.00         1
#           92       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         2
#           96       0.00      0.00      0.00         0
#           99       1.00      1.00      1.00         1
#          103       0.00      0.00      0.00         0
#          104       1.00      1.00      1.00         7
#          106       0.00      0.00      0.00         2
#          110       0.00      0.00      0.00         1
#          116       0.00      0.00      0.00         1
#          117       0.86      1.00      0.92         6
#          120       0.00      0.00      0.00         1
#          121       0.00      0.00      0.00         0
#          122       0.00      0.00      0.00         0
#          123       0.80      1.00      0.89         4
#          126       1.00      0.50      0.67         2
#          128       0.00      0.00      0.00         1
#          129       0.71      1.00      0.83         5
#          130       0.00      0.00      0.00         1
#          131       0.00      0.00      0.00         1
#          132       0.00      0.00      0.00         0
#          133       0.00      0.00      0.00         1
#          135       1.00      1.00      1.00         1
#          137       0.50      1.00      0.67         1
#          139       1.00      1.00      1.00         1
#          140       0.00      0.00      0.00         1
#          141       1.00      0.50      0.67         2
#          143       0.00      0.00      0.00         1
#          145       0.62      1.00      0.77        10
#          146       0.00      0.00      0.00         0
#          149       0.00      0.00      0.00         1
#          153       0.00      0.00      0.00         1
#          154       0.00      0.00      0.00         1
#          158       0.00      0.00      0.00         0
#          159       0.00      0.00      0.00         1
#          161       0.00      0.00      0.00         0
#          163       0.00      0.00      0.00         1
#          167       0.00      0.00      0.00         1
#          169       0.00      0.00      0.00         0
#          170       1.00      1.00      1.00         1
#          178       0.00      0.00      0.00         1
#          179       0.00      0.00      0.00         1
#
#     accuracy                           0.79       271
#    macro avg       0.36      0.37      0.36       271
# weighted avg       0.73      0.79      0.75       271
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Load new data without product names
path = 'https://raw.githubusercontent.com/gustiyaniz/Random-Forest-Classifier-Predict-Label-Product-Implemented-in-Python/main/SalesPredict.csv'
new_data = pd.read_csv(path,sep=",",header=0)
new_data['Date'] = pd.to_datetime(new_data['Date'], format='%m/%d/%Y')
new_data = new_data[['Date', 'Quantity', 'Sales', 'Profit', 'Cost']]
new_data
# Out:
#           Date  Quantity  Sales  Profit   Cost
# 0   2024-03-07         1   4000    4000      0
# 1   2024-03-07         1  21000    3150  17850
# 2   2024-03-07         1  18000    3000  15000
# 3   2024-03-07         1  28000    3150  24850
# 4   2024-03-07         1   8000    2396   5604
# ..         ...       ...    ...     ...    ...
# 360 2024-04-03         1   9000    2800   6200
# 361 2024-04-03         1  23000    2650  20350
# 362 2024-04-03         1  73000    2650  70350
# 363 2024-04-03         1  18000    2650  15350
# 364 2024-04-03         1  28000    2500  25500
#
# [365 rows x 5 columns]

# %%
# Preprocess the new data
new_data['day'] = new_data['Date'].dt.day
new_data['month'] = new_data['Date'].dt.month
new_data['year'] = new_data['Date'].dt.year
new_data['dayofweek'] = new_data['Date'].dt.dayofweek
new_data = new_data.drop(columns=['Date'])
new_data[['Quantity', 'Sales', 'Profit', 'Cost']] = scaler.transform(new_data[['Quantity', 'Sales', 'Profit', 'Cost']])
new_data
# Out:
#      Quantity     Sales    Profit      Cost  day  month  year  dayofweek
# 0   -0.101985 -0.923714  0.248703 -0.954887    7      3  2024          3
# 1   -0.101985 -0.256954 -0.155254 -0.246894    7      3  2024          3
# 2   -0.101985 -0.374617 -0.226540 -0.359935    7      3  2024          3
# 3   -0.101985  0.017594 -0.155254  0.030750    7      3  2024          3
# 4   -0.101985 -0.766829 -0.513587 -0.732613    7      3  2024          3
# ..        ...       ...       ...       ...  ...    ...   ...        ...
# 360 -0.101985 -0.727608 -0.321589 -0.708973    3      4  2024          2
# 361 -0.101985 -0.178511 -0.392875 -0.147735    3      4  2024          2
# 362 -0.101985  1.782547 -0.392875  1.835438    3      4  2024          2
# 363 -0.101985 -0.374617 -0.392875 -0.346053    3      4  2024          2
# 364 -0.101985  0.017594 -0.464162  0.056531    3      4  2024          2
#
# [365 rows x 8 columns]

# %%
# Predict the product names for the new data

predictions = model.predict(new_data)

# Decode the product names
predicted_products = label_encoder.inverse_transform(predictions)

# %%
# Add the predicted product names to the new data
new_data['predicted_product'] = predicted_products

# Save or print the results
print(new_data)
# Out:
#      Quantity     Sales    Profit      Cost  day  month  year  dayofweek  \
# 0   -0.101985 -0.923714  0.248703 -0.954887    7      3  2024          3
# 1   -0.101985 -0.256954 -0.155254 -0.246894    7      3  2024          3
# 2   -0.101985 -0.374617 -0.226540 -0.359935    7      3  2024          3
# 3   -0.101985  0.017594 -0.155254  0.030750    7      3  2024          3
# 4   -0.101985 -0.766829 -0.513587 -0.732613    7      3  2024          3
# ..        ...       ...       ...       ...  ...    ...   ...        ...
# 360 -0.101985 -0.727608 -0.321589 -0.708973    3      4  2024          2
# 361 -0.101985 -0.178511 -0.392875 -0.147735    3      4  2024          2
# 362 -0.101985  1.782547 -0.392875  1.835438    3      4  2024          2
# 363 -0.101985 -0.374617 -0.392875 -0.346053    3      4  2024          2
# 364 -0.101985  0.017594 -0.464162  0.056531    3      4  2024          2
#
#          predicted_product
# 0               Tarik Uang
# 1    5 Gb Indosat (5 Hari)
# 2       Pulsa Indosat 15 K
# 3            Pulsa Xl 25 K
# 4        Pulsa Indosat 5 K
# ..                     ...
# 360  1 Gb Indosat (3 Hari)
# 361       Top Up Dana 20 K
# 362       Top Up Dana 50 K
# 363     Pulsa Indosat 15 K
# 364      Top Up Gopay 25 K
#
# [365 rows x 9 columns]

# %%
datapredict = pd.read_csv(path,sep=",",header=0)
# Add the predicted product names to the new data
datapredict['predicted_product'] = predicted_products
print(datapredict)
# Out:
#          Date  Quantity  Sales   Cost  Profit      predicted_product
# 0    3/7/2024         1   4000      0    4000             Tarik Uang
# 1    3/7/2024         1  21000  17850    3150  5 Gb Indosat (5 Hari)
# 2    3/7/2024         1  18000  15000    3000     Pulsa Indosat 15 K
# 3    3/7/2024         1  28000  24850    3150          Pulsa Xl 25 K
# 4    3/7/2024         1   8000   5604    2396      Pulsa Indosat 5 K
# ..        ...       ...    ...    ...     ...                    ...
# 360  4/3/2024         1   9000   6200    2800  1 Gb Indosat (3 Hari)
# 361  4/3/2024         1  23000  20350    2650       Top Up Dana 20 K
# 362  4/3/2024         1  73000  70350    2650       Top Up Dana 50 K
# 363  4/3/2024         1  18000  15350    2650     Pulsa Indosat 15 K
# 364  4/3/2024         1  28000  25500    2500      Top Up Gopay 25 K
#
# [365 rows x 6 columns]

# %%
# Save the unique dataset to a CSV file
output_csv_file = "predictproduct.csv"
datapredict.to_csv(output_csv_file, index=False)
